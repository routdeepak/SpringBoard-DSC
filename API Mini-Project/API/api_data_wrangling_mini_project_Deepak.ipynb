# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'API_KEY'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?'
params = dict(key = API_KEY, start_date='2018-01-01', end_date='2018-10-10')
res = requests.get(url, params = params)
#r = requests.get('https://www.quandl.com/api/v3/datasets/FSE/EON_X.json?api_key=&start_date=2017-01-01&end_date=2017-12-31')

#print(res)
print(res.json())
# Out:
# {'dataset': {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-02-07) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-02-21T22:19:00.677Z', 'newest_available_date': '2020-02-21', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2018-01-01', 'end_date': '2018-10-10', 'data': [['2018-10-10', None, 67.3, 63.6, 63.7, None, 215727.0, 13893065.0, None, None, None], ['2018-10-09', None, 68.0, 66.15, 67.0, None, 148857.0, 9966161.0, None, None, None], ['2018-10-08', None, 69.3, 66.75, 67.1, None, 206790.0, 13989754.0, None, None, None], ['2018-10-05', None, 71.7, 68.6, 69.6, None, 195846.0, 13668103.0, None, None, None], ['2018-10-04', None, 72.4, 70.65, 71.1, None, 170698.0, 12183209.0, None, None, None], ['2018-10-02', None, 72.85, 70.55, 72.3, None, 146522.0, 10539179.0, None, None, None], ['2018-10-01', None, 73.55, 72.1, 72.95, None, 214973.0, 15638105.0, None, None, None], ['2018-09-28', None, 73.55, 71.8, 72.5, None, 160513.0, 11660089.0, None, None, None], ['2018-09-27', None, 73.6, 72.3, 72.75, None, 151651.0, 11050961.0, None, None, None], ['2018-09-26', None, 75.15, 73.1, 73.5, None, 156224.0, 11525133.0, None, None, None], ['2018-09-25', None, 75.95, 73.05, 75.0, None, 184100.0, 13728663.0, None, None, None], ['2018-09-24', None, 75.65, 74.35, 75.5, None, 128014.0, 9612143.0, None, None, None], ['2018-09-21', None, 75.6, 74.35, 74.6, None, 626537.0, 46792528.0, None, None, None], ['2018-09-20', None, 75.7, 73.6, 74.35, None, 118408.0, 8827636.0, None, None, None], ['2018-09-19', None, 76.1, 75.35, 75.65, None, 105147.0, 7961441.0, None, None, None], ['2018-09-18', None, 76.0, 75.25, 75.95, None, 87488.0, 6634355.0, None, None, None], ['2018-09-17', None, 75.95, 75.0, 75.55, None, 91799.0, 6939819.0, None, None, None], ['2018-09-14', None, 76.25, 75.6, 75.95, None, 97874.0, 7434019.0, None, None, None], ['2018-09-13', None, 76.5, 75.65, 76.15, None, 87473.0, 6653544.0, None, None, None], ['2018-09-12', None, 76.45, 75.8, 76.2, None, 119365.0, 9093783.0, None, None, None], ['2018-09-11', None, 76.6, 75.35, 75.75, None, 98418.0, 7481820.0, None, None, None], ['2018-09-10', None, 76.25, 75.3, 76.15, None, 74999.0, 5691773.0, None, None, None], ['2018-09-07', None, 76.2, 74.45, 75.8, None, 100377.0, 7579300.0, None, None, None], ['2018-09-06', None, 76.5, 74.95, 76.15, None, 92228.0, 7026341.0, None, None, None], ['2018-09-05', None, 75.95, 74.65, 75.3, None, 103213.0, 7777480.0, None, None, None], ['2018-09-04', None, 76.7, 75.6, 76.15, None, 120202.0, 9162584.0, None, None, None], ['2018-09-03', None, 76.8, 75.9, 76.5, None, 105650.0, 8083383.0, None, None, None], ['2018-08-31', None, 76.55, 76.0, 76.3, None, 61684.0, 4707947.0, None, None, None], ['2018-08-30', None, 76.7, 75.9, 76.45, None, 88920.0, 6788099.0, None, None, None], ['2018-08-29', None, 76.85, 75.6, 76.6, None, 74039.0, 5666123.0, None, None, None], ['2018-08-28', None, 75.7, 73.5, 75.65, None, 123300.0, 9262964.0, None, None, None], ['2018-08-27', None, 74.15, 72.6, 73.6, None, 168351.0, 12372154.0, None, None, None], ['2018-08-24', None, 75.05, 72.0, 74.7, None, 149755.0, 11084458.0, None, None, None], ['2018-08-23', None, 75.55, 73.85, 74.6, None, 77293.0, 5775269.0, None, None, None], ['2018-08-22', None, 75.2, 73.7, 75.2, None, 57768.0, 4313345.0, None, None, None], ['2018-08-21', None, 74.55, 73.0, 73.9, None, 75511.0, 5575558.0, None, None, None], ['2018-08-20', None, 73.4, 72.25, 73.15, None, 80822.0, 5887516.0, None, None, None], ['2018-08-17', None, 72.35, 71.05, 71.9, None, 84990.0, 6096498.0, No ...

# %%
print(type(res))
json_data = res.json()
print(type(json_data))
# Out:
# <class 'requests.models.Response'>
# <class 'dict'>

# %%
header_data = res.headers
for i in header_data.keys():
    print(i)

print(type(header_data))
# Out:
# Date
# Content-Type
# Content-Length
# Connection
# Set-Cookie
# Allow
# Cache-Control
# Content-Encoding
# ETag
# Vary
# X-Content-Type-Options
# X-Frame-Options
# X-Rack-CORS
# X-RateLimit-Limit
# X-RateLimit-Remaining
# X-Request-Id
# X-Runtime
# X-XSS-Protection
# CF-Cache-Status
# Expect-CT
# Server
# CF-RAY
# <class 'requests.structures.CaseInsensitiveDict'>

# %%
header_data
# Out:
# {'Date': 'Sun, 23 Feb 2020 04:36:15 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '4683', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dc695985f6961f796b50e3b8a5e1b6fe21582432573; expires=Tue, 24-Mar-20 04:36:13 GMT; path=/; domain=.quandl.com; HttpOnly; SameSite=Lax', 'Allow': 'GET, HEAD, POST, PUT, DELETE, OPTIONS, PATCH', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Content-Encoding': 'gzip', 'ETag': 'W/"17bd9558502d2dd6a56502785008b470"', 'Vary': 'Origin', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-Rack-CORS': 'miss; no-origin', 'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '8', 'X-Request-Id': '9288ef8f-188e-499a-aacb-a65d89acf63f', 'X-Runtime': '0.108942', 'X-XSS-Protection': '1; mode=block', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '56967f634c8d6991-BOM'}

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
sample_col_list = json_data['dataset']['column_names']
sample_data_list = json_data['dataset']['data']

# %%
sample_col_list
sample_data_list
# Out:
# [['2018-10-10',
#   None,
#   67.3,
#   63.6,
#   63.7,
#   None,
#   215727.0,
#   13893065.0,
#   None,
#   None,
#   None],
#  ['2018-10-09',
#   None,
#   68.0,
#   66.15,
#   67.0,
#   None,
#   148857.0,
#   9966161.0,
#   None,
#   None,
#   None],
#  ['2018-10-08',
#   None,
#   69.3,
#   66.75,
#   67.1,
#   None,
#   206790.0,
#   13989754.0,
#   None,
#   None,
#   None],
#  ['2018-10-05',
#   None,
#   71.7,
#   68.6,
#   69.6,
#   None,
#   195846.0,
#   13668103.0,
#   None,
#   None,
#   None],
#  ['2018-10-04',
#   None,
#   72.4,
#   70.65,
#   71.1,
#   None,
#   170698.0,
#   12183209.0,
#   None,
#   None,
#   None],
#  ['2018-10-02',
#   None,
#   72.85,
#   70.55,
#   72.3,
#   None,
#   146522.0,
#   10539179.0,
#   None,
#   None,
#   None],
#  ['2018-10-01',
#   None,
#   73.55,
#   72.1,
#   72.95,
#   None,
#   214973.0,
#   15638105.0,
#   None,
#   None,
#   None],
#  ['2018-09-28',
#   None,
#   73.55,
#   71.8,
#   72.5,
#   None,
#   160513.0,
#   11660089.0,
#   None,
#   None,
#   None],
#  ['2018-09-27',
#   None,
#   73.6,
#   72.3,
#   72.75,
#   None,
#   151651.0,
#   11050961.0,
#   None,
#   None,
#   None],
#  ['2018-09-26',
#   None,
#   75.15,
#   73.1,
#   73.5,
#   None,
#   156224.0,
#   11525133.0,
#   None,
#   None,
#   None],
#  ['2018-09-25',
#   None,
#   75.95,
#   73.05,
#   75.0,
#   None,
#   184100.0,
#   13728663.0,
#   None,
#   None,
#   None],
#  ['2018-09-24',
#   None,
#   75.65,
#   74.35,
#   75.5,
#   None,
#   128014.0,
#   9612143.0,
#   None,
#   None,
#   None],
#  ['2018-09-21',
#   None,
#   75.6,
#   74.35,
#   74.6,
#   None,
#   626537.0,
#   46792528.0,
#   None,
#   None,
#   None],
#  ['2018-09-20',
#   None,
#   75.7,
#   73.6,
#   74.35,
#   None,
#   118408.0,
#   8827636.0,
#   None,
#   None,
#   None],
#  ['2018-09-19',
#   None,
#   76.1,
#   75.35,
#   75.65,
#   None,
#   105147.0,
#   7961441.0,
#   None,
#   None,
#   None],
#  ['2018-09-18',
#   None,
#   76.0,
#   75.25,
#   75.95,
#   None,
#   87488.0,
#   6634355.0,
#   None,
#   None,
#   None],
#  ['2018-09-17',
#   None,
#   75.95,
#   75.0,
#   75.55,
#   None,
#   91799.0,
#   6939819.0,
#   None,
#   None,
#   None],
#  ['2018-09-14',
#   None,
#   76.25,
#   75.6,
#   75.95,
#   None,
#   97874.0,
#   7434019.0,
#   None,
#   None,
#   None],
#  ['2018-09-13',
#   None,
#   76.5,
#   75.65,
#   76.15,
#   None,
#   87473.0,
#   6653544.0,
#   None,
#   None,
#   None],
#  ['2018-09-12',
#   None,
#   76.45,
#   75.8,
#   76.2,
#   None,
#   119365.0,
#   9093783.0,
#   None,
#   None,
#   None],
#  ['2018-09-11',
#   None,
#   76.6,
#   75.35,
#   75.75,
#   None,
#   98418.0,
#   7481820.0,
#   None,
#   None,
#   None],
#  ['2018-09-10',
#   None,
#   76.25,
#   75.3,
#   76.15,
#   None,
#   74999.0,
#   5691773.0,
#   None,
#   None,
#   None],
#  ['2018-09-07',
#   None,
#   76.2,
#   74.45,
#   75.8,
#   None,
#   100377.0,
#   7579300.0,
#   None,
#   None,
#   None],
#  ['2018-09-06',
#   None,
#   76.5,
#   74.95,
#   76.15,
#   None,
#   92228.0,
#   7026341.0,
#   None,
#   None,
#   None],
#  ['2018-09-05',
#   None,
#   75.95,
#   74.65,
#   75.3,
#   None,
#   103213.0,
#   7777480.0,
#   None,
#   None,
#   None],
#  ['2018-09-04',
#   None,
#   76.7,
#   75.6,
#   76.15,
#   None,
#   120202.0,
#   9162584.0,
#   None,
#   None,
#   None],
#  ['2018-09-03',
#   None,
#   76.8,
#   75.9,
#   76.5,
#   None,
#   105650.0,
#   8083383.0,
#   None,
#   None,
#   None],
#  ['2018-08-31',
#   None,
#   76.55,
#   76.0,
#   76.3,
#   None,
#   61684.0,
#   4707947.0,
#   None,
#   None,
#   None],
#  ['2018-08-30',
#   None,
#   76.7,
#   75.9,
#   76.45,
#   None,
#   88920.0,
#   6788099.0,
#   None,
#   None,
#   None],
#  ['2018-08-29',
#   None,
#   76.85,
#   75.6,
#   76.6,
#   None,
#   74039.0,
#   5666123.0,
#   None,
#   None,
#   None],
#  ['2018-08-28',
#   None,
#   75.7,
#   73.5,
#   75.65,
#   None,
#   123300.0,
#   9262964.0,
#   None,
#   None,
#   None],
#  ['2018-08-27',
#   None,
#   74.15,
#   72.6,
#   73.6,
#   None,
#   168351.0,
#   12372154.0,
#   None,
#   None,
#   None],
#  ['2018-08-24',
#   None,
#   75.05,
#   72.0,
#   74.7,
#   None,
#   149755.0,
#   11084458.0,
#   None,
#   None,
#   None],
#  ['2018-08-23',
#   None,
#   75.55,
#   73.85,
#   74.6,
#   None,
#   77293.0,
#   5775269.0,
#   None,
#   None,
#   None],
#  ['2018-08-22',
#   None,
#   75.2,
#   73.7,
#   75.2,
#   None,
#   57768.0,
#   4313345.0,
#   None,
#   None,
#   None],
#  ['2018-08-21',
#   None,
#   74.55,
#   73.0,
#   73.9,
#   None,
#   75511.0,
#   5575558.0,
#   None,
#   None,
#   None],
#  ['2018-08-20',
#   None,
#   73.4,
#   72.25,
#   73.15,
#   None,
#   80822.0,
#   5887516.0,
#   None,
#   None,
#   None],
#  ['2018-08-17',
#   None,
#   72.35,
#   71.05,
#   71.9,
#   None,
#   84990.0,
#   6096498.0,
#   None,
#   None,
#   None],
#  ['2018-08-16',
#   None,
#   72.2,
#   71.2,
#   71.85,
#   None,
#   115538.0,
#   8281588.0,
#   None,
#   None,
#   None],
#  ['2018-08-15',
#   None,
#   73.35,
#   71.9,
#   72.0,
#   None,
#   150595.0,
#   10905690.0,
#   None,
#   None,
#   None],
#  ['2018-08-14',
#   None,
#   74.0,
#   72.25,
#   73.0,
#   None,
#   138029.0,
#   10067922.0,
#   None,
#   None,
#   None],
#  ['2018-08-13',
#   None,
#   73.95,
#   71.1,
#   73.8,
#   None,
#   93352.0,
#   6792143.0,
#   None,
#   None,
#   None],
#  ['2018-08-10',
#   None,
#   71.75,
#   68.85,
#   71.25,
#   None,
#   83816.0,
#   5939899.0,
#   None,
#   None,
#   None],
#  ['2018-08-09',
#   None,
#   69.35,
#   68.65,
#   69.35,
#   None,
#   58850.0,
#   4068455.0,
#   None,
#   None,
#   None],
#  ['2018-08-08',
#   None,
#   68.75,
#   67.7,
#   68.65,
#   None,
#   47181.0,
#   3225473.0,
#   None,
#   None,
#   None],
#  ['2018-08-07',
#   None,
#   69.05,
#   67.85,
#   67.85,
#   None,
#   55295.0,
#   3764837.0,
#   None,
#   None,
#   None],
#  ['2018-08-06',
#   None,
#   69.8,
#   67.15,
#   68.9,
#   None,
#   88362.0,
#   6085409.0,
#   None,
#   None,
#   None],
#  ['2018-08-03',
#   None,
#   69.1,
#   67.3,
#   67.45,
#   None,
#   110757.0,
#   7511670.0,
#   None,
#   None,
#   None],
#  ['2018-08-02',
#   None,
#   68.15,
#   67.25,
#   67.6,
#   None,
#   70142.0,
#   4743048.0,
#   None,
#   None,
#   None],
#  ['2018-08-01',
#   None,
#   68.05,
#   66.5,
#   67.9,
#   None,
#   76796.0,
#   5205129.0,
#   None,
#   None,
#   None],
#  ['2018-07-31',
#   None,
#   67.55,
#   65.9,
#   66.45,
#   None,
#   84168.0,
#   5597404.0,
#   None,
#   None,
#   None],
#  ['2018-07-30',
#   None,
#   67.35,
#   66.85,
#   67.2,
#   None,
#   35731.0,
#   2399532.0,
#   None,
#   None,
#   None],
#  ['2018-07-27',
#   None,
#   67.6,
#   67.05,
#   67.2,
#   None,
#   39471.0,
#   2655320.0,
#   None,
#   None,
#   None],
#  ['2018-07-26',
#   None,
#   67.75,
#   66.75,
#   67.15,
#   None,
#   62259.0,
#   4185095.0,
#   None,
#   None,
#   None],
#  ['2018-07-25',
#   None,
#   67.2,
#   65.6,
#   67.1,
#   None,
#   73666.0,
#   4919963.0,
#   None,
#   None,
#   None],
#  ['2018-07-24',
#   None,
#   66.5,
#   65.3,
#   65.7,
#   None,
#   71397.0,
#   4704819.0,
#   None,
#   None,
#   None],
#  ['2018-07-23',
#   None,
#   65.95,
#   65.05,
#   65.95,
#   None,
#   58031.0,
#   3817744.0,
#   None,
#   None,
#   None],
#  ['2018-07-20',
#   None,
#   66.4,
#   65.25,
#   65.75,
#   None,
#   84008.0,
#   5527735.0,
#   None,
#   None,
#   None],
#  ['2018-07-19',
#   None,
#   66.9,
#   64.85,
#   65.0,
#   None,
#   79571.0,
#   5203540.0,
#   None,
#   None,
#   None],
#  ['2018-07-18',
#   None,
#   66.8,
#   66.1,
#   66.8,
#   None,
#   53036.0,
#   3530697.0,
#   None,
#   None,
#   None],
#  ['2018-07-17',
#   None,
#   66.0,
#   64.5,
#   65.9,
#   None,
#   46492.0,
#   3046350.0,
#   None,
#   None,
#   None],
#  ['2018-07-16',
#   None,
#   64.65,
#   63.55,
#   64.6,
#   None,
#   57261.0,
#   3680350.0,
#   None,
#   None,
#   None],
#  ['2018-07-13',
#   None,
#   65.5,
#   63.9,
#   64.0,
#   None,
#   63161.0,
#   4064001.0,
#   None,
#   None,
#   None],
#  ['2018-07-12',
#   None,
#   65.05,
#   63.25,
#   64.9,
#   None,
#   85581.0,
#   5511566.0,
#   None,
#   None,
#   None],
#  ['2018-07-11',
#   None,
#   63.5,
#   62.7,
#   62.9,
#   None,
#   59396.0,
#   3740208.0,
#   None,
#   None,
#   None],
#  ['2018-07-10',
#   None,
#   63.4,
#   62.6,
#   63.35,
#   None,
#   74335.0,
#   4695641.0,
#   None,
#   None,
#   None],
#  ['2018-07-09',
#   None,
#   63.25,
#   62.25,
#   62.5,
#   None,
#   61523.0,
#   3852056.0,
#   None,
#   None,
#   None],
#  ['2018-07-06',
#   None,
#   63.7,
#   61.3,
#   62.2,
#   None,
#   89445.0,
#   5580643.0,
#   None,
#   None,
#   None],
#  ['2018-07-05',
#   None,
#   61.6,
#   60.85,
#   61.4,
#   None,
#   53878.0,
#   3301491.0,
#   None,
#   None,
#   None],
#  ['2018-07-04',
#   None,
#   61.15,
#   59.85,
#   61.15,
#   None,
#   66921.0,
#   4074096.0,
#   None,
#   None,
#   None],
#  ['2018-07-03',
#   None,
#   60.4,
#   57.6,
#   60.1,
#   None,
#   117722.0,
#   6993521.0,
#   None,
#   None,
#   None],
#  ['2018-07-02',
#   None,
#   58.4,
#   57.7,
#   58.05,
#   None,
#   33629.0,
#   1954900.0,
#   None,
#   None,
#   None],
#  ['2018-06-29',
#   None,
#   58.8,
#   58.15,
#   58.45,
#   None,
#   62647.0,
#   3660865.0,
#   None,
#   None,
#   None],
#  ['2018-06-28',
#   None,
#   59.25,
#   57.6,
#   57.95,
#   None,
#   47505.0,
#   2766758.0,
#   None,
#   None,
#   None],
#  ['2018-06-27',
#   None,
#   59.65,
#   58.6,
#   58.95,
#   None,
#   96154.0,
#   5685432.0,
#   None,
#   None,
#   None],
#  ['2018-06-26',
#   None,
#   59.7,
#   58.9,
#   59.25,
#   None,
#   68693.0,
#   4072540.0,
#   None,
#   None,
#   None],
#  ['2018-06-25',
#   None,
#   59.75,
#   58.75,
#   58.75,
#   None,
#   52522.0,
#   3112244.0,
#   None,
#   None,
#   None],
#  ['2018-06-22',
#   None,
#   60.85,
#   59.7,
#   59.75,
#   None,
#   43763.0,
#   2629860.0,
#   None,
#   None,
#   None],
#  ['2018-06-21',
#   None,
#   61.1,
#   60.15,
#   60.55,
#   None,
#   60336.0,
#   3654176.0,
#   None,
#   None,
#   None],
#  ['2018-06-20',
#   None,
#   60.85,
#   60.1,
#   60.75,
#   None,
#   60501.0,
#   3668176.0,
#   None,
#   None,
#   None],
#  ['2018-06-19',
#   None,
#   60.2,
#   59.45,
#   59.9,
#   None,
#   69191.0,
#   4140192.0,
#   None,
#   None,
#   None],
#  ['2018-06-18',
#   None,
#   61.55,
#   60.0,
#   60.35,
#   None,
#   77196.0,
#   4663863.0,
#   None,
#   None,
#   None],
#  ['2018-06-15',
#   None,
#   62.45,
#   60.9,
#   61.45,
#   None,
#   461929.0,
#   28395821.0,
#   None,
#   None,
#   None],
#  ['2018-06-14',
#   None,
#   62.35,
#   61.4,
#   62.15,
#   None,
#   72484.0,
#   4498956.0,
#   None,
#   None,
#   None],
#  ['2018-06-13',
#   None,
#   61.85,
#   61.3,
#   61.55,
#   None,
#   77752.0,
#   4786379.0,
#   None,
#   None,
#   None],
#  ['2018-06-12',
#   None,
#   62.05,
#   60.9,
#   61.2,
#   None,
#   62494.0,
#   3830707.0,
#   None,
#   None,
#   None],
#  ['2018-06-11',
#   None,
#   61.5,
#   60.85,
#   61.35,
#   None,
#   56533.0,
#   3461580.0,
#   None,
#   None,
#   None],
#  ['2018-06-07',
#   None,
#   60.85,
#   59.65,
#   59.95,
#   None,
#   84215.0,
#   5062604.0,
#   None,
#   None,
#   None],
#  ['2018-06-06',
#   None,
#   60.75,
#   59.45,
#   60.55,
#   None,
#   119380.0,
#   7202424.0,
#   None,
#   None,
#   None],
#  ['2018-06-05',
#   None,
#   59.75,
#   58.95,
#   59.55,
#   None,
#   98799.0,
#   5871733.0,
#   None,
#   None,
#   None],
#  ['2018-06-04',
#   None,
#   59.45,
#   58.7,
#   59.2,
#   None,
#   99669.0,
#   5893346.0,
#   None,
#   None,
#   None],
#  ['2018-06-01',
#   None,
#   59.35,
#   56.9,
#   58.9,
#   None,
#   121922.0,
#   7149977.0,
#   None,
#   None,
#   None],
#  ['2018-05-31',
#   None,
#   59.6,
#   58.75,
#   59.15,
#   None,
#   108504.0,
#   6416256.0,
#   None,
#   None,
#   None],
#  ['2018-05-30',
#   None,
#   60.25,
#   58.65,
#   58.7,
#   None,
#   97364.0,
#   5758058.0,
#   None,
#   None,
#   None],
#  ['2018-05-28',
#   None,
#   61.3,
#   60.2,
#   61.25,
#   None,
#   88908.0,
#   5407976.0,
#   None,
#   None,
#   None],
#  ['2018-05-25',
#   None,
#   60.25,
#   58.5,
#   60.25,
#   None,
#   99172.0,
#   5921845.0,
#   None,
#   None,
#   None],
#  ['2018-05-24',
#   None,
#   58.8,
#   57.7,
#   58.5,
#   None,
#   72723.0,
#   4250331.0,
#   None,
#   None,
#   None],
#  ['2018-05-23',
#   None,
#   58.05,
#   57.0,
#   57.9,
#   None,
#   46697.0,
#   2690820.0,
#   None,
#   None,
#   None],
#  ['2018-05-22',
#   None,
#   58.55,
#   57.65,
#   58.05,
#   None,
#   76281.0,
#   4428520.0,
#   None,
#   None,
#   None],
#  ['2018-05-18',
#   None,
#   59.0,
#   57.1,
#   57.95,
#   None,
#   81077.0,
#   4707479.0,
#   None,
#   None,
#   None],
#  ['2018-05-17',
#   None,
#   57.35,
#   56.7,
#   57.25,
#   None,
#   69080.0,
#   3946079.0,
#   None,
#   None,
#   None],
#  ['2018-05-16',
#   None,
#   58.05,
#   56.9,
#   57.0,
#   None,
#   56288.0,
#   3228216.0,
#   None,
#   None,
#   None],
#  ['2018-05-15',
#   None,
#   57.65,
#   55.75,
#   57.0,
#   None,
#   100626.0,
#   5724266.0,
#   None,
#   None,
#   None],
#  ['2018-05-14',
#   None,
#   57.95,
#   57.15,
#   57.8,
#   None,
#   50399.0,
#   2905596.0,
#   None,
#   None,
#   None],
#  ['2018-05-11',
#   None,
#   58.15,
#   56.95,
#   57.35,
#   None,
#   63082.0,
#   3621924.0,
#   None,
#   None,
#   None],
#  ['2018-05-10',
#   None,
#   58.15,
#   57.5,
#   58.15,
#   None,
#   20795.0,
#   1206105.0,
#   None,
#   None,
#   None],
#  ['2018-05-09',
#   None,
#   57.6,
#   56.75,
#   57.6,
#   None,
#   52426.0,
#   3002890.0,
#   None,
#   None,
#   None],
#  ['2018-05-08',
#   None,
#   59.15,
#   57.35,
#   57.35,
#   None,
#   64959.0,
#   3738329.0,
#   None,
#   None,
#   None],
#  ['2018-05-07',
#   None,
#   58.95,
#   57.4,
#   58.95,
#   None,
#   52378.0,
#   3060029.0,
#   None,
#   None,
#   None],
#  ['2018-05-04',
#   None,
#   57.9,
#   56.95,
#   57.15,
#   None,
#   52985.0,
#   3032353.0,
#   None,
#   None,
#   None],
#  ['2018-05-03',
#   None,
#   57.6,
#   56.8,
#   57.1,
#   None,
#   60236.0,
#   3444406.0,
#   None,
#   None,
#   None],
#  ['2018-05-02',
#   None,
#   58.1,
#   56.4,
#   57.45,
#   None,
#   88108.0,
#   5054341.0,
#   None,
#   None,
#   None],
#  ['2018-04-30',
#   None,
#   56.45,
#   56.0,
#   56.3,
#   None,
#   58326.0,
#   3280897.0,
#   None,
#   None,
#   None],
#  ['2018-04-27',
#   None,
#   56.85,
#   55.05,
#   56.0,
#   None,
#   86375.0,
#   4847905.0,
#   None,
#   None,
#   None],
#  ['2018-04-26',
#   None,
#   55.15,
#   54.3,
#   55.05,
#   None,
#   51209.0,
#   2810881.0,
#   None,
#   None,
#   None],
#  ['2018-04-25',
#   None,
#   54.95,
#   54.0,
#   54.75,
#   None,
#   91616.0,
#   5003149.0,
#   None,
#   None,
#   None],
#  ['2018-04-24',
#   None,
#   54.75,
#   54.15,
#   54.6,
#   None,
#   59651.0,
#   3252235.0,
#   None,
#   None,
#   None],
#  ['2018-04-23',
#   None,
#   54.9,
#   53.75,
#   54.7,
#   None,
#   67059.0,
#   3656093.0,
#   None,
#   None,
#   None],
#  ['2018-04-20',
#   None,
#   54.1,
#   53.55,
#   53.9,
#   None,
#   56023.0,
#   3021011.0,
#   None,
#   None,
#   None],
#  ['2018-04-19',
#   None,
#   54.1,
#   52.8,
#   53.9,
#   None,
#   65723.0,
#   3533700.0,
#   None,
#   None,
#   None],
#  ['2018-04-18',
#   None,
#   53.25,
#   52.2,
#   53.25,
#   None,
#   72894.0,
#   3863971.0,
#   None,
#   None,
#   None],
#  ['2018-04-17',
#   None,
#   52.25,
#   51.65,
#   52.0,
#   None,
#   57127.0,
#   2971940.0,
#   None,
#   None,
#   None],
#  ['2018-04-16',
#   None,
#   52.4,
#   51.05,
#   51.8,
#   None,
#   125663.0,
#   6513055.0,
#   None,
#   None,
#   None],
#  ['2018-04-13',
#   None,
#   52.95,
#   51.7,
#   52.5,
#   None,
#   59575.0,
#   3122819.0,
#   None,
#   None,
#   None],
#  ['2018-04-12',
#   None,
#   52.2,
#   50.85,
#   52.0,
#   None,
#   77912.0,
#   4033804.0,
#   None,
#   None,
#   None],
#  ['2018-04-11',
#   None,
#   52.2,
#   51.15,
#   51.3,
#   None,
#   94078.0,
#   4884841.0,
#   None,
#   None,
#   None],
#  ['2018-04-10',
#   None,
#   53.55,
#   52.1,
#   52.2,
#   None,
#   117708.0,
#   6192817.0,
#   None,
#   None,
#   None],
#  ['2018-04-09',
#   None,
#   53.0,
#   51.75,
#   53.0,
#   None,
#   72459.0,
#   3812927.0,
#   None,
#   None,
#   None],
#  ['2018-04-06',
#   None,
#   51.75,
#   51.15,
#   51.7,
#   None,
#   37429.0,
#   1931216.0,
#   None,
#   None,
#   None],
#  ['2018-04-05',
#   None,
#   51.8,
#   51.0,
#   51.65,
#   None,
#   45012.0,
#   2317907.0,
#   None,
#   None,
#   None],
#  ['2018-04-04',
#   None,
#   51.8,
#   50.75,
#   50.9,
#   None,
#   69739.0,
#   3559486.0,
#   None,
#   None,
#   None],
#  ['2018-04-03',
#   None,
#   51.7,
#   50.8,
#   51.65,
#   None,
#   92025.0,
#   4734817.0,
#   None,
#   None,
#   None],
#  ['2018-03-29',
#   None,
#   52.15,
#   51.15,
#   51.85,
#   None,
#   56160.0,
#   2908967.0,
#   None,
#   None,
#   None],
#  ['2018-03-28',
#   None,
#   52.1,
#   51.0,
#   51.55,
#   None,
#   66175.0,
#   3412277.0,
#   None,
#   None,
#   None],
#  ['2018-03-27',
#   None,
#   52.1,
#   50.35,
#   51.7,
#   None,
#   89089.0,
#   4582469.0,
#   None,
#   None,
#   None],
#  ['2018-03-26',
#   None,
#   50.95,
#   49.62,
#   50.05,
#   None,
#   80836.0,
#   4062036.0,
#   None,
#   None,
#   None],
#  ['2018-03-23',
#   None,
#   49.68,
#   48.6,
#   49.42,
#   None,
#   90793.0,
#   4466193.0,
#   None,
#   None,
#   None],
#  ['2018-03-22',
#   None,
#   49.7,
#   49.28,
#   49.6,
#   None,
#   83655.0,
#   4141232.0,
#   None,
#   None,
#   None],
#  ['2018-03-21',
#   None,
#   50.1,
#   49.48,
#   49.56,
#   None,
#   43165.0,
#   2143464.0,
#   None,
#   None,
#   None],
#  ['2018-03-20',
#   None,
#   50.05,
#   49.44,
#   50.0,
#   None,
#   46223.0,
#   2304364.0,
#   None,
#   None,
#   None],
#  ['2018-03-19',
#   None,
#   49.88,
#   48.9,
#   49.5,
#   None,
#   66792.0,
#   3303500.0,
#   None,
#   None,
#   None],
#  ['2018-03-16',
#   None,
#   50.55,
#   49.22,
#   49.22,
#   None,
#   352062.0,
#   17355294.0,
#   None,
#   None,
#   None],
#  ['2018-03-15',
#   None,
#   50.4,
#   49.4,
#   50.2,
#   None,
#   47455.0,
#   2374579.0,
#   None,
#   None,
#   None],
#  ['2018-03-14',
#   None,
#   50.5,
#   49.84,
#   50.0,
#   None,
#   56492.0,
#   2832056.0,
#   None,
#   None,
#   None],
#  ['2018-03-13',
#   None,
#   52.15,
#   50.3,
#   50.4,
#   None,
#   86809.0,
#   4435040.0,
#   None,
#   None,
#   None],
#  ['2018-03-12',
#   None,
#   51.8,
#   50.6,
#   51.7,
#   None,
#   86202.0,
#   4434869.0,
#   None,
#   None,
#   None],
#  ['2018-03-09',
#   None,
#   50.7,
#   50.05,
#   50.5,
#   None,
#   66937.0,
#   3376280.0,
#   None,
#   None,
#   None],
#  ['2018-03-08',
#   None,
#   50.4,
#   49.48,
#   50.25,
#   None,
#   68085.0,
#   3406641.0,
#   None,
#   None,
#   None],
#  ['2018-03-07',
#   None,
#   49.68,
#   48.7,
#   49.56,
#   None,
#   95964.0,
#   4731213.0,
#   None,
#   None,
#   None],
#  ['2018-03-06',
#   None,
#   50.05,
#   49.26,
#   49.58,
#   None,
#   108000.0,
#   5352665.0,
#   None,
#   None,
#   None],
#  ['2018-03-05',
#   None,
#   49.56,
#   48.5,
#   49.22,
#   None,
#   67895.0,
#   3345047.0,
#   None,
#   None,
#   None],
#  ['2018-03-02',
#   None,
#   49.7,
#   48.94,
#   49.02,
#   None,
#   77271.0,
#   3803033.0,
#   None,
#   None,
#   None],
#  ['2018-03-01',
#   None,
#   50.8,
#   50.05,
#   50.25,
#   None,
#   121721.0,
#   6130791.0,
#   None,
#   None,
#   None],
#  ['2018-02-28',
#   None,
#   51.2,
#   50.35,
#   50.8,
#   None,
#   51766.0,
#   2633558.0,
#   None,
#   None,
#   None],
#  ['2018-02-27',
#   None,
#   51.25,
#   50.05,
#   50.8,
#   None,
#   91014.0,
#   4602394.0,
#   None,
#   None,
#   None],
#  ['2018-02-26',
#   None,
#   51.3,
#   49.9,
#   51.15,
#   None,
#   70849.0,
#   3602935.0,
#   None,
#   None,
#   None],
#  ['2018-02-23',
#   None,
#   50.65,
#   49.62,
#   50.15,
#   None,
#   85529.0,
#   4282416.0,
#   None,
#   None,
#   None],
#  ['2018-02-22',
#   None,
#   50.5,
#   49.04,
#   50.3,
#   None,
#   78981.0,
#   3950282.0,
#   None,
#   None,
#   None],
#  ['2018-02-21',
#   None,
#   49.78,
#   49.08,
#   49.72,
#   None,
#   54366.0,
#   2695174.0,
#   None,
#   None,
#   None],
#  ['2018-02-20',
#   None,
#   50.35,
#   49.62,
#   49.98,
#   None,
#   72611.0,
#   3625953.0,
#   None,
#   None,
#   None],
#  ['2018-02-19',
#   None,
#   50.8,
#   49.72,
#   49.78,
#   None,
#   63379.0,
#   3166398.0,
#   None,
#   None,
#   None],
#  ['2018-02-16',
#   None,
#   51.0,
#   49.38,
#   50.75,
#   None,
#   85521.0,
#   4317347.0,
#   None,
#   None,
#   None],
#  ['2018-02-15',
#   None,
#   49.96,
#   48.88,
#   49.34,
#   None,
#   98735.0,
#   4867477.0,
#   None,
#   None,
#   None],
#  ['2018-02-14',
#   None,
#   49.66,
#   48.6,
#   49.48,
#   None,
#   67429.0,
#   3328497.0,
#   None,
#   None,
#   None],
#  ['2018-02-13',
#   None,
#   50.05,
#   48.82,
#   48.88,
#   None,
#   82639.0,
#   4062581.0,
#   None,
#   None,
#   None],
#  ['2018-02-12',
#   None,
#   50.6,
#   47.38,
#   49.76,
#   None,
#   115700.0,
#   5741391.0,
#   None,
#   None,
#   None],
#  ['2018-02-09',
#   None,
#   50.45,
#   48.62,
#   49.38,
#   None,
#   94709.0,
#   4675500.0,
#   None,
#   None,
#   None],
#  ['2018-02-08',
#   None,
#   51.55,
#   48.9,
#   49.06,
#   None,
#   135352.0,
#   6740505.0,
#   None,
#   None,
#   None],
#  ['2018-02-07',
#   None,
#   51.55,
#   49.28,
#   51.45,
#   None,
#   152153.0,
#   7735813.0,
#   None,
#   None,
#   None],
#  ['2018-02-06',
#   None,
#   50.1,
#   45.8,
#   49.54,
#   None,
#   283106.0,
#   13844855.0,
#   None,
#   None,
#   None],
#  ['2018-02-05',
#   None,
#   50.6,
#   48.92,
#   50.1,
#   None,
#   162996.0,
#   8145273.0,
#   None,
#   None,
#   None],
#  ['2018-02-02',
#   None,
#   51.95,
#   50.5,
#   50.6,
#   None,
#   102655.0,
#   5225053.0,
#   None,
#   None,
#   None],
#  ['2018-02-01',
#   None,
#   53.2,
#   51.85,
#   52.05,
#   None,
#   74150.0,
#   3879807.0,
#   None,
#   None,
#   None],
#  ['2018-01-31',
#   None,
#   53.2,
#   51.9,
#   52.75,
#   None,
#   86020.0,
#   4527940.0,
#   None,
#   None,
#   None],
#  ['2018-01-30',
#   None,
#   52.95,
#   52.0,
#   52.35,
#   None,
#   64262.0,
#   3366028.0,
#   None,
#   None,
#   None],
#  ['2018-01-29',
#   None,
#   54.25,
#   52.75,
#   53.0,
#   None,
#   73679.0,
#   3917787.0,
#   None,
#   None,
#   None],
#  ['2018-01-26',
#   None,
#   53.35,
#   52.05,
#   53.35,
#   None,
#   41175.0,
#   2182371.0,
#   None,
#   None,
#   None],
#  ['2018-01-25',
#   None,
#   53.1,
#   51.9,
#   52.35,
#   None,
#   60347.0,
#   3161715.0,
#   None,
#   None,
#   None],
#  ['2018-01-24',
#   None,
#   52.55,
#   51.95,
#   52.4,
#   None,
#   57224.0,
#   2995735.0,
#   None,
#   None,
#   None],
#  ['2018-01-23',
#   None,
#   52.95,
#   52.25,
#   52.5,
#   None,
#   65281.0,
#   3427258.0,
#   None,
#   None,
#   None],
#  ['2018-01-22',
#   None,
#   53.45,
#   51.8,
#   52.45,
#   None,
#   75149.0,
#   3928095.0,
#   None,
#   None,
#   None],
#  ['2018-01-19',
#   None,
#   53.55,
#   52.55,
#   53.25,
#   None,
#   58592.0,
#   3116070.0,
#   None,
#   None,
#   None],
#  ['2018-01-18',
#   None,
#   52.35,
#   51.65,
#   52.3,
#   None,
#   46582.0,
#   2429147.0,
#   None,
#   None,
#   None],
#  ['2018-01-17',
#   None,
#   51.75,
#   51.05,
#   51.7,
#   None,
#   57919.0,
#   2985441.0,
#   None,
#   None,
#   None],
#  ['2018-01-16',
#   None,
#   51.8,
#   51.2,
#   51.55,
#   None,
#   62912.0,
#   3239390.0,
#   None,
#   None,
#   None],
#  ['2018-01-15',
#   None,
#   52.35,
#   51.3,
#   51.75,
#   None,
#   83289.0,
#   4305279.0,
#   None,
#   None,
#   None],
#  ['2018-01-12',
#   None,
#   53.15,
#   51.05,
#   52.3,
#   None,
#   238861.0,
#   12470941.0,
#   None,
#   None,
#   None],
#  ['2018-01-11',
#   None,
#   55.25,
#   53.7,
#   54.4,
#   None,
#   173473.0,
#   9450601.0,
#   None,
#   None,
#   None],
#  ['2018-01-02',
#   52.05,
#   52.4,
#   51.2,
#   51.4,
#   None,
#   54435.0,
#   2807533.0,
#   None,
#   None,
#   None]]

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# ## ANSWERS

# %% [markdown]
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

# %%
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?'
params = dict(key = API_KEY, start_date='2017-01-01', end_date='2017-12-31')
res = requests.get(url, params = params)
#res = requests.get('https://www.quandl.com/api/v3/datasets/FSE/EON_X.json?api_key=&start_date=2017-01-01&end_date=2017-12-31')
print(res.status_code)
print(res.json())
# Out:
# 200
# {'dataset': {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-02-07) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-02-21T22:19:00.677Z', 'newest_available_date': '2020-02-21', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'data': [['2017-12-29', 51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None], ['2017-12-28', 51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None], ['2017-12-27', 51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None], ['2017-12-22', 51.05, 51.5, 50.92, 51.32, None, 71165.0, 3641949.0, None, None, None], ['2017-12-21', 51.16, 51.52, 50.9, 51.4, None, 120649.0, 6179433.0, None, None, None], ['2017-12-20', 51.88, 52.04, 51.2, 51.27, None, 50587.0, 2610258.0, None, None, None], ['2017-12-19', 52.73, 52.73, 51.07, 51.66, None, 137313.0, 7102361.0, None, None, None], ['2017-12-18', 52.37, 52.75, 51.61, 52.62, None, 129733.0, 6770499.0, None, None, None], ['2017-12-15', 52.7, 52.7, 51.64, 52.01, None, 204080.0, 10596319.0, None, None, None], ['2017-12-14', 53.11, 53.54, 52.15, 52.67, None, 132981.0, 7016953.0, None, None, None], ['2017-12-13', 52.64, 53.35, 52.48, 53.09, None, 128434.0, 6801159.0, None, None, None], ['2017-12-12', 52.29, 53.1, 51.82, 52.43, None, 87911.0, 4615924.0, None, None, None], ['2017-12-11', 52.28, 52.45, 51.26, 52.14, None, 71817.0, 3724193.0, None, None, None], ['2017-12-08', 51.5, 52.83, 51.28, 52.12, None, 109157.0, 5690648.0, None, None, None], ['2017-12-07', 50.89, 51.47, 50.81, 51.47, None, 48123.0, 2463848.0, None, None, None], ['2017-12-06', 50.8, 51.11, 50.39, 50.89, None, 88730.0, 4504075.0, None, None, None], ['2017-12-05', 51.21, 51.38, 50.4, 51.25, None, 83023.0, 4231971.0, None, None, None], ['2017-12-04', 49.5, 51.23, 49.5, 51.14, None, 94385.0, 4800027.0, None, None, None], ['2017-12-01', 49.52, 50.49, 49.17, 49.86, None, 101733.0, 5065932.0, None, None, None], ['2017-11-30', 48.64, 49.84, 48.28, 49.7, None, 123019.0, 6085171.0, None, None, None], ['2017-11-29', 49.64, 49.64, 48.7, 48.75, None, 67342.0, 3292223.0, None, None, None], ['2017-11-28', 49.09, 49.89, 49.03, 49.25, None, 42669.0, 2107358.0, None, None, None], ['2017-11-27', 49.13, 49.73, 48.96, 49.2, None, 102180.0, 5055762.0, None, None, None], ['2017-11-24', 49.11, 49.41, 48.87, 49.11, None, 50350.0, 2472842.0, None, None, None], ['2017-11-23', 48.8, 49.46, 48.45, 49.2, None, 38834.0, 1909352.0, None, None, None], ['2017-11-22', 48.4, 49.61, 48.39, 48.8, None, 91142.0, 4478093.0, None, None, None], ['2017-11-21', 47.25, 48.59, 46.78, 48.39, None, 78502.0, 3782098.0, None, None, None], ['2017-11-20', 46.57, 47.38, 46.54, 47.04, None, 97252.0, 4563515.0, None, None, None], ['2017-11-17', 47.03, 47.15, 46.8, 46.84, None, 54107.0, 2540820.0, None, None, None], ['2017-11-16', 47.09, 47.23, 46.55, 47.03, None, 89373.0, 4195732.0, None, None, None], ['2017-11-15', 47.98, 48.01, 46.75, 47.05, None, 67593.0, 3188321.0, None, None, None], ['2017-11-14', 48.4, 48.9, 47.84, 48.0, None, 67672.0, 3259979.0, None, None, None], ['2017-11-13', 48.38, 48.61, 47.76, 48.34, None, 76286.0, 3681337.0, None, None, None], ['2017-11-10', 47.3, 48.89, 47.16, 48.34, None, 90245.0, 4361552.0, None, None, None], ['2017-11-09', 47.65, 48.06, 47.09, 47.21, None, 120268.0, 5712034.0, None, None, None], ['2017-11-08', 46.42, 47.72, 46.42, 47.47, None, 94195.0, 4463935.0, None, None, None], ['2017-11-07', 46.16, 46.33, 45.84, 46.26, None, 48152.0, 2224221.0, None, None, None], ['2017-11-06', 45. ...

# %% [markdown]
# 2. Convert the returned JSON object into a Python dictionary.

# %%
json_data = res.json()
print(type(json_data))
res.status_code
# Out:
# <class 'dict'>
# 200

# %% [markdown]
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.

# %%
col_list = json_data['dataset']['column_names']
data_list = json_data['dataset']['data']

assert len(col_list) == len(data_list[0])

# 'Open' Prices are stored in the second column (index: 1)
print(col_list[1])

# Create a list of opening prices using list comprehension 
# Will be iterating over len(data_list)
# Make sure to include conditional to drop 'None' values since sorted() can't compare 'None' to 'float'

opening_price_list = [data_list[i][1] for i in range(len(data_list)) if data_list[i][1] != None]
opening_price_list = sorted(opening_price_list)

lowest = opening_price_list[0]
highest = opening_price_list[-1]

statement = "During the period of 2017-01-01 and 2017-12-31, the lowest opening price \
was ${}. The highest opening price was ${}."
print(statement.format(lowest, highest))
# Out:
# Open
# During the period of 2017-01-01 and 2017-12-31, the lowest opening price was $34.0. The highest opening price was $53.11.

# %% [markdown]
# 4. What was the largest change in any one day (based on High and Low price)?

# %%
# Index 2 is High / Index 3 is Low 
col_list[2]
col_list[3] 

# High - Low 

price_change_list = [(data_list[i][2] - data_list[i][3]) for i in range(len(data_list)) if ((data_list[i][2] != None) & (data_list[i][3] != None))]

price_change_list = sorted(price_change_list, reverse=True) # descending order
largest = price_change_list[0] 
# print(type(largest))

statement = "Largest change in any one day (based on High and Low price) is ${0:.2f}"

print(statement.format(largest))
# Out:
# Largest change in any one day (based on High and Low price) is $2.81

# %% [markdown]
# 5. What was the largest change between any two days (based on Closing Price)?

# %%
# print(col_list)

# Index 4 is Close Price 
col_list[4]

# between any two days means consecutive days 
# I took the absolute value of the difference 

closing_price_change = [abs(data_list[i][4] - data_list[i+1][4]) for i in range(len(data_list) - 1) if (data_list[i][4] != None)]

closing_price_change = sorted(closing_price_change, reverse=True)
change = closing_price_change[0]

statement = "Largest change between any two days (based on Closing Price) is ${0:.2f}"

print(statement.format(change))
# Out:
# Largest change between any two days (based on Closing Price) is $2.56

# %% [markdown]
# 6. What was the average daily trading volume during this year?

# %%
range(len(data_list))# print(col_list)

# Index 6 is Traded Volume
col_list[6]

trade_vol = [data_list[i][6] for i in range(len(data_list)) if (data_list[i][6] != None)]
average_volume = sum(trade_vol)/len(trade_vol)

statement = "Average Daily Volume during the year 2017 is {0:.3f}"

print(statement.format(average_volume))
# Out:
# Average Daily Volume during the year 2017 is 89124.337

# %% [markdown]
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
trade_vol = [data_list[i][6] for i in range(len(data_list)) if (data_list[i][6] != None)]

def median_of_list(vol_list):
    
    # important to sort the values first to get the median! 
    vol_list = sorted(vol_list)
    length = len(vol_list)
    
    if (length % 2 == 1):
        idx = (length // 2)     
                                 
        median = vol_list[idx]    
        

    elif (length % 2 == 0):
        idx = int(length / 2)
        median = (vol_list[idx - 1] + vol_list[idx]) / 2

    return median

median = median_of_list(trade_vol)
statement = "Median trading volume during the year of 2017 was {0:.3f}"

print(statement.format(median))
# Out:
# Median trading volume during the year of 2017 was 76286.000
